# %%
from imdb import Imdb
from reuters import Reuters
from boston_housing import BostonHousing

# %% [markdown]
# Test IMDB (Binary classification (positive/negative reviews) with sigmoid activation and binary crossentropy loss.)

# %%
imdb = Imdb()

# %%
imdb.prepare_data()

# %%
imdb.build_model()
# Out:
# c:\Users\Mukul\anaconda3\envs\teachable\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
imdb.train(epochs=10)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5252 - loss: 0.6896 - val_accuracy: 0.6366 - val_loss: 0.6351
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7288 - loss: 0.5826 - val_accuracy: 0.8116 - val_loss: 0.4417
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8358 - loss: 0.4009 - val_accuracy: 0.8610 - val_loss: 0.3589
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8633 - loss: 0.3372 - val_accuracy: 0.7860 - val_loss: 0.4354
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8809 - loss: 0.2945 - val_accuracy: 0.8238 - val_loss: 0.3786
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8968 - loss: 0.2571 - val_accuracy: 0.8812 - val_loss: 0.2941
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9034 - loss: 0.2471 - val_accuracy: 0.8834 - val_loss: 0.2900
# Epoch 8/10
# ...

# %%
imdb.plot_loss()

# %%
imdb.plot_accuracy()

# %%
imdb.evaluate()
# Out:
# Test Loss: 0.3103
# Test Accuracy: 0.8718

# %% [markdown]
#  Test Reuters (Multiclass classification (multiple news categories) with softmax activation and categorical crossentropy loss.)

# %%
reuters = Reuters()

# %%
reuters.prepare_data()
# Out:
# ...
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
reuters.build_model()

# %%
reuters.train(epochs=10)
# Out:
# Epoch 1/10
# 225/225 [==============================] - 4s 12ms/step - loss: 1.5901 - accuracy: 0.6625 - val_loss: 1.0704 - val_accuracy: 0.7641
# Epoch 2/10
# 225/225 [==============================] - 2s 11ms/step - loss: 0.6775 - accuracy: 0.8477 - val_loss: 0.9105 - val_accuracy: 0.8041
# Epoch 3/10
# 225/225 [==============================] - 3s 11ms/step - loss: 0.3532 - accuracy: 0.9219 - val_loss: 0.8945 - val_accuracy: 0.8102
# Epoch 4/10
# 225/225 [==============================] - 2s 11ms/step - loss: 0.2290 - accuracy: 0.9493 - val_loss: 0.9376 - val_accuracy: 0.8052
# Epoch 5/10
# 225/225 [==============================] - 3s 12ms/step - loss: 0.1767 - accuracy: 0.9562 - val_loss: 0.9683 - val_accuracy: 0.7930
# Epoch 6/10
# 225/225 [==============================] - 2s 10ms/step - loss: 0.1564 - accuracy: 0.9585 - val_loss: 0.9654 - val_accuracy: 0.8024
# Epoch 7/10
# ...

# %%
reuters.plot_loss()

# %%
reuters.plot_accuracy()

# %%
reuters.evaluate()
# Out:
# Test Loss: 1.1099
# Test Accuracy: 0.7881

# %% [markdown]
# Test Boston Housing ( Regression (predicting continuous house prices) with no activation in the final layer and mean squared error loss.)

# %%
boston = BostonHousing()

# %%
boston.prepare_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
boston.build_model()

# %%
boston.train(epochs=50)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 20ms/step - loss: 565.1005 - mae: 21.9761 - val_loss: 612.6316 - val_mae: 23.0446
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 529.9235 - mae: 21.1867 - val_loss: 573.9805 - val_mae: 22.2452
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 491.3448 - mae: 20.3185 - val_loss: 527.8231 - val_mae: 21.2359
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 442.5622 - mae: 19.1521 - val_loss: 467.2794 - val_mae: 19.8189
# Epoch 5/50
# 11/11 [==============================] - 0s 5ms/step - loss: 381.2242 - mae: 17.5620 - val_loss: 387.4450 - val_mae: 17.8219
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 301.2639 - mae: 15.3410 - val_loss: 293.2113 - val_mae: 15.1110
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 211.4740 - mae: 12.5120 - val_loss: 199.7006 - val_mae: 11.8407
# Epoch 8/50
# ...

# %%
boston.plot_loss()

# %%
boston.evaluate()
# Out:
# Test Loss (MSE): 24.8803
# Test MAE: 3.3341
